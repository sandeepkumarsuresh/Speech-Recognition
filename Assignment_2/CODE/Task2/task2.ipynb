# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import pandas as pd



rate , audio = wav.read('/home/tenet/Desktop/CS22Z121/Assignment_2/a_16_1_c.wav')
fft_audio_a = np.fft.rfft(audio)
fft_audio_freq_a = np.fft.rfftfreq(len(audio),1/rate)
plt.plot(fft_audio_freq_a,abs(fft_audio_a))
plt.ylabel("Magnitude")
plt.xlabel("Frequency")
plt.title("DFT Spectrum of Vowel A")
plt.show()

# length = data.shape[0]/rate
# time = np.linspace(0., length, data.shape[0])
# plt.plot(time, data[:, 0], label="Left channel")
# plt.plot(time, data[:, 1], label="Right channel")
# plt.legend()
# plt.xlabel("Time [s]")
# plt.ylabel("Amplitude")
# plt.show()

#audio = librosa.load('a.wav' , sr=None ,dtype='float32')
#print(audio)
# fft_audio = fft(audio)
# plt.plot(abs(fft_audio))
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft



rate , audio = wav.read('/home/tenet/Desktop/CS22Z121/Assignment_2/e_16_1_c.wav')
fft_audio_e =np.fft.rfft(audio)
frequency_e = np.fft.rfftfreq(len(audio),1/rate)


plt.plot(abs(fft_audio_e))
plt.ylabel("Magnitude")
plt.xlabel("Frequency")
plt.title("DFT Spectrum of Vowel E")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft



rate , audio = wav.read('/home/tenet/Desktop/CS22Z121/Assignment_2/i_16_1_c.wav')
fft_audio_i = np.fft.rfft(audio)
plt.plot(abs(fft_audio_i))
plt.ylabel("Magnitude")
plt.xlabel("Frequency")
plt.title("DFT Spectrum of Vowel I")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft



rate , audio = wav.read('/home/tenet/Desktop/CS22Z121/Assignment_2/o_16_1_c.wav')
fft_audio_o = np.fft.rfft(audio)
plt.plot(abs(fft_audio_o))
plt.ylabel("Magnitude")
plt.xlabel("Frequency")
plt.title("DFT Spectrum of Vowel O")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft



rate , audio = wav.read('/home/tenet/Desktop/CS22Z121/Assignment_2/u_16_1_c.wav')
fft_audio_u = np.fft.rfft(audio)
plt.plot(abs(fft_audio_u))
plt.ylabel("Magnitude")
plt.xlabel("Frequency")
plt.title("DFT Spectrum of Vowel U")
plt.show()

# %%
plt.rcParams.update({'figure.figsize':(10,7), 'figure.dpi':100})
fig, ax = plt.subplots(2,3)
fig.tight_layout(h_pad=4)


ax[0,0].plot(abs(fft_audio_a))
ax[0,0].set(title = 'DFT of Vowel A' , xlabel='Frequency',ylabel='Magnitude')

ax[0,1].plot(abs(fft_audio_e))
ax[0,1].set(title = 'DFT of Vowel E' , xlabel='Frequency',ylabel='Magnitude')

ax[0,2].plot(abs(fft_audio_i))
ax[0,2].set(title = 'DFT of Vowel I' , xlabel='Frequency',ylabel='Magnitude')

ax[1,0].plot(abs(fft_audio_o))
ax[1,0].set(title = 'DFT of Vowel O' , xlabel='Frequency',ylabel='Magnitude')

ax[1,1].set_visible(False)

ax[1,2].plot(abs(fft_audio_u))
ax[1,2].set(title = 'DFT of Vowel U' , xlabel='Frequency',ylabel='Magnitude')



plt.show()
