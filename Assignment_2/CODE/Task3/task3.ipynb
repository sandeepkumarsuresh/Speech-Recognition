# %%
import parselmouth 
from parselmouth import praat
import matplotlib.pyplot as plt

# %%
test1 = '/home/tenet/Desktop/CS22Z121/Assignment_2/Task2/a_16_1.wav'
test2 = '/home/tenet/Desktop/CS22Z121/Assignment_2/Task2/i_16_1.wav'

# %%
sound_a = parselmouth.Sound(test1)
sound_i = parselmouth.Sound(test2)

# %%
f0min=75
f0max=300
pointProcess = praat.call(sound_a, "To PointProcess (periodic, cc)", f0min, f0max)
pointProcess = praat.call(sound_i, "To PointProcess (periodic, cc)", f0min, f0max)

# %%
formants_a = praat.call(sound_a, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
formants_i = praat.call(sound_i, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)

# %%
numPoints = praat.call(pointProcess, "Get number of points")
f1_a = []
f2_a = []
f3_list = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_a, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_a, "Get value at time", 2, t, 'Hertz', 'Linear')
    f1_a.append(f1)
    f2_a.append(f2)

# %%
numPoints = praat.call(pointProcess, "Get number of points")
f1_i = []
f2_i = []
f3_list = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_i, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_i, "Get value at time", 2, t, 'Hertz', 'Linear')
    f1_i.append(f1)
    f2_i.append(f2)

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [6,6]

# %%
ka = '/home/tenet/Desktop/CS22Z121/Assignment_2/Task3/ka_16.wav'
sound_ka = parselmouth.Sound(ka)
f0min=75
f0max=300
pointProcess = praat.call(sound_ka, "To PointProcess (periodic, cc)", f0min, f0max)
formants_ka = praat.call(sound_ka, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
numPoints = praat.call(pointProcess, "Get number of points")
f1_ka = []
f2_ka = []
f3_list = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_ka, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_ka, "Get value at time", 2, t, 'Hertz', 'Linear')
    f3 = praat.call(formants_ka, "Get value at time", 3, t, 'Hertz', 'Linear')
    f1_ka.append(f1)
    f2_ka.append(f2)
    f3_list.append(f3)

plt.scatter(f1_a,f2_a ,c="blue")
plt.scatter(f1_ka,f2_ka ,c="yellow")
plt.xlabel('F1')
plt.ylabel('F2')
plt.title('F1 F2 Comparison of /a/ and /ka/')

plt.legend(['a','ka'])
plt.show()

# %%
ki = '/home/tenet/Desktop/CS22Z121/Assignment_2/Task3/ki.wav'
sound_ki = parselmouth.Sound(ki)
f0min=75
f0max=300
pointProcess = praat.call(sound_ki, "To PointProcess (periodic, cc)", f0min, f0max)
formants_ki = praat.call(sound_ki, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
numPoints = praat.call(pointProcess, "Get number of points")
f1_ki = []
f2_ki = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_ki, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_ki, "Get value at time", 2, t, 'Hertz', 'Linear')
    f1_ki.append(f1)
    f2_ki.append(f2)

plt.scatter(f1_i,f2_i ,c="red")
plt.scatter(f1_ki,f2_ki ,c="yellow")
plt.legend(['i','ki'])
plt.xlabel('F1')
plt.ylabel('F2')
plt.title('F1 F2 Comparison of /i/ and /ki/')
plt.show()

# %%
ja = '/home/tenet/Desktop/CS22Z121/Assignment_2/Task3/ja.wav'
sound_ja = parselmouth.Sound(ja)
f0min=75
f0max=300
pointProcess = praat.call(sound_ja, "To PointProcess (periodic, cc)", f0min, f0max)
formants_ja = praat.call(sound_ja, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
numPoints = praat.call(pointProcess, "Get number of points")
f1_ja = []
f2_ja = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_ja, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_ja, "Get value at time", 2, t, 'Hertz', 'Linear')
    f1_ja.append(f1)
    f2_ja.append(f2)

plt.scatter(f1_a,f2_a ,c="blue")
plt.scatter(f1_ja,f2_ja ,c="red")
plt.legend(['a','ja'])
plt.xlabel('F1')
plt.ylabel('F2')
plt.title('F1 F2 Comparison of /a/ and /ja/')
plt.show()

# %%
daa = 'daa.wav'
sound_daa = parselmouth.Sound(daa)
f0min=75
f0max=300
pointProcess = praat.call(sound_daa, "To PointProcess (periodic, cc)", f0min, f0max)
formants_daa = praat.call(sound_daa, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
numPoints = praat.call(pointProcess, "Get number of points")
f1_daa = []
f2_daa = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_daa, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_daa, "Get value at time", 2, t, 'Hertz', 'Linear')
    f1_daa.append(f1)
    f2_daa.append(f2)

plt.scatter(f1_a,f2_a ,c="blue")
plt.scatter(f1_daa,f2_daa ,c="red")
plt.legend(['a','daa'])
plt.show()

# %%
tha = 'tha.wav'
sound_tha = parselmouth.Sound(tha)
f0min=75
f0max=300
pointProcess = praat.call(sound_tha, "To PointProcess (periodic, cc)", f0min, f0max)
formants_tha = praat.call(sound_tha, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
numPoints = praat.call(pointProcess, "Get number of points")
f1_tha = []
f2_tha = []
for point in range(0, numPoints):
    point += 1
    t = praat.call(pointProcess, "Get time from index", point)
    f1 = praat.call(formants_tha, "Get value at time", 1, t, 'Hertz', 'Linear')
    f2 = praat.call(formants_tha, "Get value at time", 2, t, 'Hertz', 'Linear')
    f1_tha.append(f1)
    f2_tha.append(f2)

plt.scatter(f1_a,f2_a ,c="blue")
plt.scatter(f1_tha,f2_tha ,c="yellow")
plt.legend(['a','tha'])
plt.show()

# %%
fig, ax = plt.subplots(2, 2)
fig.tight_layout(h_pad=8)

ax[0,0].scatter(f1_a,f2_a ,c="blue")
ax[0,0].scatter(f1_ka,f2_ka ,c="yellow")
ax[0,0].set(title = '/a/ vs /ka/' , xlabel="F1",ylabel="F2")
ax[0,0].legend(['a','ka'])



ax[0,1].scatter(f1_i,f2_i ,c="red")
ax[0,1].scatter(f1_ki,f2_ki ,c="lime")
ax[0,1].set(title = '/i/ vs /ki/' , xlabel="F1",ylabel="F2")
ax[0,1].legend(['i','ki'])

ax[1,0].scatter(f1_a,f2_a ,c="blue")
ax[1,0].scatter(f1_daa,f2_daa ,c="red")
ax[1,0].set(title = '/a/ vs /daa/' , xlabel="F1",ylabel="F2")
ax[1,0].legend(['a','daa'])


ax[1,1].scatter(f1_a,f2_a ,c="blue")
ax[1,1].scatter(f1_tha,f2_tha ,c="yellow")
ax[1,1].set(title = '/a/ vs /tha/' , xlabel="F1",ylabel="F2")
ax[1,1].legend(['a','tha'])

plt.show()
